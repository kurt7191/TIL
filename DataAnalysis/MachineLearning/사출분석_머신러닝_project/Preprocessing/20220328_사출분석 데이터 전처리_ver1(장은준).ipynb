# %% [markdown]
# ## ver1 purpose
# - 지도학습 데이터 labeled_data 전처리
#   - 종속변수와 상관관계 높은 변수 선정하여 outlier 및 null 값 제거(다 확인 힘드니) (완료)
#   - 데이터 값이 이상한 변수 삭제 (완료)
#   - 종속변수 label 숫자로 변환 (완료)

# %% [markdown]
# # 1. 데이터 불러오기

# %% [markdown]
# ## 1.1 디렉토리 설정 및 데이터 로드

# %%
import os
import pandas as pd


#디렉토리 설정
os.chdir('/content/drive/MyDrive/Data/dataset')

#labeled_data 로드
labeled_data = pd.read_csv('labeled_data.csv')

#moldset_labeled data 로드 (moldset_labeled.csv)
moldset_labeled_data = pd.read_csv('moldset_labeled.csv')

#unlabeled data 로드(unlabeled_data.csv)
unlabeled_data = pd.read_csv('unlabeled_data.csv')

# %%
#데이터 확인

labeled_data
moldset_labeled_data
unlabeled_data
print('labeled_data length : {}개'.format(labeled_data.shape[0]))
print('moldset_labeled_data length : {}개'.format(moldset_labeled_data.shape[0]))
print('unlabeled_data length : {}개'.format(unlabeled_data.shape[0]))
# Out:
# labeled_data length : 7996개
# moldset_labeled_data length : 2607개
# unlabeled_data length : 795315개

# %% [markdown]
# # 2. 데이터 변수 제거(labeled_data)

# %%
#labeled Data info 확인
#변수 null값 및 data type 확인

labeled_data.T
# Out:
#                                               0                         1     \
# _id                       5f8928bb9c0189cc666ef19b  5f8928de9c0189cc666ef20b
# TimeStamp                      2020-10-16 04:57:47       2020-10-16 04:58:48
# PART_FACT_PLAN_DATE         2020-10-16 오전 12:00:00    2020-10-16 오전 12:00:00
# PART_FACT_SERIAL                                24                        24
# PART_NAME                    CN7 W/S SIDE MLD'G RH     CN7 W/S SIDE MLD'G RH
# EQUIP_CD                                       S14                       S14
# EQUIP_NAME                              650톤-우진2호기                650톤-우진2호기
# PassOrFail                                       Y                         Y
# Reason                                        None                      None
# Injection_Time                                9.59                       9.6
# Filling_Time                                  4.47                      4.48
# Plasticizing_Time                            16.92                     16.91
# Cycle_Time                                   59.52                 59.580002
# Clamp_Close_Time                              7.13                      7.13
# Cushion_Position                        653.409973                653.409973
# Switch_Over_Position                           0.0                       0.0
# Plasticizing_Position                    68.849998                 68.839996
# Clamp_Open_Position                      647.98999                 647.98999
# Max_Injection_Speed                      55.400002                 55.299999
# Max_Screw_RPM                            30.700001                 30.799999
# Average_Screw_RPM                            292.5                     292.5
# Max_Injection_Pressure                  141.800003                141.800003
# Max_Switch_Over_Pressure                136.800003                136.899994
# Max_Back_Pressure                        37.400002                      37.5
# Average_Back_Pressure                    59.299999                 59.299999
# Barrel_Temperature_1                         276.5                276.200012
# Barrel_Temperature_2                    274.700012                     275.5
# Barrel_Temperature_3                    274.799988                275.299988
# Barrel_Temperature_4                    269.200012                270.799988
# Barrel_Temperature_5                         255.0                254.699997
# Barrel_Temperature_6                    229.699997                     229.5
# Barrel_Temperature_7                           0.0                       0.0
# Hopper_Temperature                       66.300003                 67.199997
# Mold_Temperature_1                             0.0                       0.0
# Mold_Temperature_2                             0.0                       0.0
# Mold_Temperature_3                       24.799999                 24.799999
# Mold_Temperature_4                            27.5                      27.6
# Mold_Temperature_5                             0.0                       0.0
# Mold_Temperature_6                             0.0                       0.0
# Mold_Temperature_7                             0.0                       0.0
# Mold_Temperature_8                             0.0                       0.0
# Mold_Temperature_9                             0.0                       0.0
# Mold_Temperature_10                            0.0                       0.0
# Mold_Temperature_11                            0.0                       0.0
# Mold_Temperature_12                            0.0                       0.0
#
#                                               2                         3     \
# _id                       5f8928df9c0189cc666ef213  5f8928f39c0189cc666ef25e
# TimeStamp                      2020-10-16 04:58:48       2020-10-16 04:59:48
# PART_FACT_PLAN_DATE         2020-10-16 오전 12:00:00    2020-10-16 오전 12:00:00
# PART_FACT_SERIAL                                23                        23
# PART_NAME                    CN7 W/S SIDE MLD'G LH     CN7 W/S SIDE MLD'G LH
# EQUIP_CD                                       S14                       S14
# EQUIP_NAME                              650톤-우진2호기                650톤-우진2호기
# PassOrFail                                       Y                         Y
# Reason                                        None                      None
# Injection_Time                                 9.6                      9.59
# Filling_Time                                  4.48                      4.48
# Plasticizing_Time                            16.91                     16.91
# Cycle_Time                               59.580002                 59.560001
# Clamp_Close_Time                              7.13                      7.13
# Cushion_Position                        653.409973                653.419983
# Switch_Over_Position                           0.0                       0.0
# Plasticizing_Position                    68.839996                 68.839996
# Clamp_Open_Position                      647.98999                 647.98999
# Max_Injection_Speed                      55.299999                 55.299999
# Max_Screw_RPM                            30.799999                      31.0
# Average_Screw_RPM                            292.5                     292.5
# Max_Injection_Pressure                  141.800003                141.800003
# Max_Switch_Over_Pressure                136.899994                136.800003
# Max_Back_Pressure                             37.5                      37.5
# Average_Back_Pressure                    59.299999                 59.299999
# Barrel_Temperature_1                    276.200012                     276.5
# Barrel_Temperature_2                         275.5                     275.0
# Barrel_Temperature_3                    275.299988                275.399994
# Barrel_Temperature_4                    270.799988                271.100006
# Barrel_Temperature_5                    254.699997                254.899994
# Barrel_Temperature_6                         229.5                     230.0
# Barrel_Temperature_7                           0.0                       0.0
# Hopper_Temperature                       67.199997                 66.900002
# Mold_Temperature_1                             0.0                       0.0
# Mold_Temperature_2                             0.0                       0.0
# Mold_Temperature_3                       24.799999                      25.0
# Mold_Temperature_4                            27.6                      27.6
# Mold_Temperature_5                             0.0                       0.0
# Mold_Temperature_6                             0.0                       0.0
# Mold_Temperature_7                             0.0                       0.0
# Mold_Temperature_8                             0.0                       0.0
# Mold_Temperature_9                             0.0                       0.0
# Mold_Temperature_10                            0.0                       0.0
# Mold_Temperature_11                            0.0                       0.0
# Mold_Temperature_12                            0.0                       0.0
#
#                                               4                         5     \
# _id                       5f8928f59c0189cc666ef265  5f89294b9c0189cc666ef5b9
# TimeStamp                      2020-10-16 04:59:48       2020-10-16 05:00:46
# PART_FACT_PLAN_DATE         2020-10-16 오전 12:00:00    2020-10-16 오전 12:00:00
# PART_FACT_SERIAL                                24                        24
# PART_NAME                    CN7 W/S SIDE MLD'G RH     CN7 W/S SIDE MLD'G RH
# EQUIP_CD                                       S14                       S14
# EQUIP_NAME                              650톤-우진2호기                650톤-우진2호기
# PassOrFail                                       Y                         Y
# Reason                                        None                      None
# Injection_Time                                9.59                      9.58
# Filling_Time                                  4.48                      4.46
# Plasticizing_Time                            16.91                      16.9
# Cycle_Time                               59.560001                 59.580002
# Clamp_Close_Time                              7.13                      7.13
# Cushion_Position                        653.419983                653.409973
# Switch_Over_Position                           0.0                       0.0
# Plasticizing_Position                    68.839996                 68.839996
# Clamp_Open_Position                      647.98999                 647.98999
# Max_Injection_Speed                      55.299999                 55.599998
# Max_Screw_RPM                                 31.0                      30.9
# Average_Screw_RPM                            292.5                     292.5
# Max_Injection_Pressure                  141.800003                141.699997
# Max_Switch_Over_Pressure                136.800003                136.399994
# Max_Back_Pressure                             37.5                 37.700001
# Average_Back_Pressure                    59.299999                 59.400002
# Barrel_Temperature_1                         276.5                276.299988
# Barrel_Temperature_2                         275.0                275.299988
# Barrel_Temperature_3                    275.399994                275.200012
# Barrel_Temperature_4                    271.100006                271.399994
# Barrel_Temperature_5                    254.899994                     255.0
# Barrel_Temperature_6                         230.0                     230.0
# Barrel_Temperature_7                           0.0                       0.0
# Hopper_Temperature                       66.900002                      67.5
# Mold_Temperature_1                             0.0                       0.0
# Mold_Temperature_2                             0.0                       0.0
# Mold_Temperature_3                            25.0                      25.0
# Mold_Temperature_4                            27.6                      27.6
# Mold_Temperature_5                             0.0                       0.0
# Mold_Temperature_6                             0.0                       0.0
# Mold_Temperature_7                             0.0                       0.0
# Mold_Temperature_8                             0.0                       0.0
# Mold_Temperature_9                             0.0                       0.0
# Mold_Temperature_10                            0.0                       0.0
# Mold_Temperature_11                            0.0                       0.0
# Mold_Temperature_12                            0.0                       0.0
#
#                                               6                         7     \
# _id                       5f89294c9c0189cc666ef5d6  5f8929989c0189cc666ef872
# TimeStamp                      2020-10-16 05:00:46       2020-10-16 05:01:46
# PART_FACT_PLAN_DATE         2020-10-16 오전 12:00:00    2020-10-16 오전 12:00:00
# PART_FACT_SERIAL                                23                        24
# PART_NAME                    CN7 W/S SIDE MLD'G LH     CN7 W/S SIDE MLD'G RH
# EQUIP_CD                                       S14                       S14
# EQUIP_NAME                              650톤-우진2호기                650톤-우진2호기
# PassOrFail                                       Y                         Y
# Reason                                        None                      None
# Injection_Time                                9.58                      9.58
# Filling_Time                                  4.46                      4.46
# Plasticizing_Time                             16.9                     16.92
# Cycle_Time                               59.580002                 59.560001
# Clamp_Close_Time                              7.13                      7.13
# Cushion_Position                        653.409973                653.409973
# Switch_Over_Position                           0.0                       0.0
# Plasticizing_Position                    68.839996                 68.849998
# Clamp_Open_Position                      647.98999                 647.98999
# Max_Injection_Speed                      55.599998                      55.5
# Max_Screw_RPM                                 30.9                      30.6
# Average_Screw_RPM                            292.5                292.399994
# Max_Injection_Pressure                  141.699997                141.800003
# Max_Switch_Over_Pressure                136.399994                136.699997
# Max_Back_Pressure                        37.700001                 37.400002
# Average_Back_Pressure                    59.400002                 59.299999
# Barrel_Temperature_1                    276.299988                275.799988
# Barrel_Temperature_2                    275.299988                275.399994
# Barrel_Temperature_3                    275.200012                     275.0
# Barrel_Temperature_4                    271.399994                271.299988
# Barrel_Temperature_5                         255.0                     255.0
# Barrel_Temperature_6                         230.0                     230.0
# Barrel_Temperature_7                           0.0                       0.0
# Hopper_Temperature                            67.5                      67.0
# Mold_Temperature_1                             0.0                       0.0
# Mold_Temperature_2                             0.0                       0.0
# Mold_Temperature_3                            25.0                      25.0
# Mold_Temperature_4                            27.6                      27.6
# Mold_Temperature_5                             0.0                       0.0
# Mold_Temperature_6                             0.0                       0.0
# Mold_Temperature_7                             0.0                       0.0
# Mold_Temperature_8                             0.0                       0.0
# Mold_Temperature_9                             0.0                       0.0
# Mold_Temperature_10                            0.0                       0.0
# Mold_Temperature_11                            0.0                       0.0
# Mold_Temperature_12                            0.0                       0.0
#
#                                               8                         9     \
# _id                       5f8929999c0189cc666ef87d  5f8929a89c0189cc666ef8fe
# TimeStamp                      2020-10-16 05:01:46       2020-10-16 05:02:46
# PART_FACT_PLAN_DATE         2020-10-16 오전 12:00:00    2020-10-16 오전 12:00:00
# PART_FACT_SERIAL                                23                        24
# PART_NAME                    CN7 W/S SIDE MLD'G LH     CN7 W/S SIDE MLD'G RH
# EQUIP_CD                                       S14                       S14
# EQUIP_NAME                              650톤-우진2호기                650톤-우진2호기
# PassOrFail                                       Y                         Y
# Reason                                        None                      None
# Injection_Time                                9.58                      9.57
# Filling_Time                                  4.46                      4.45
# Plasticizing_Time                            16.92                     16.91
# Cycle_Time                               59.560001                     59.52
# Clamp_Close_Time                              7.13                      7.14
# Cushion_Position                        653.409973                653.409973
# Switch_Over_Position                           0.0                       0.0
# Plasticizing_Position                    68.849998                 68.830002
# Clamp_Open_Position                      647.98999                 647.98999
# Max_Injection_Speed                           55.5                 55.700001
# Max_Screw_RPM                                 30.6                 30.799999
# Average_Screw_RPM                       292.399994                     292.5
# Max_Injection_Pressure                  141.800003                141.600006
# Max_Switch_Over_Pressure                136.699997                136.399994
# Max_Back_Pressure                        37.400002                 37.099998
# Average_Back_Pressure                    59.299999                 59.099998
# Barrel_Temperature_1                    275.799988                275.700012
# Barrel_Temperature_2                    275.399994                274.899994
# Barrel_Temperature_3                         275.0                274.799988
# Barrel_Temperature_4                    271.299988                270.799988
# Barrel_Temperature_5                         255.0                255.399994
# Barrel_Temperature_6                         230.0                230.100006
# Barrel_Temperature_7                           0.0                       0.0
# Hopper_Temperature                            67.0                 66.699997
# Mold_Temperature_1                             0.0                       0.0
# Mold_Temperature_2                             0.0                       0.0
# Mold_Temperature_3                            25.0                 24.799999
# Mold_Temperature_4                            27.6                      27.5
# Mold_Temperature_5                             0.0                       0.0
# Mold_Temperature_6                             0.0                       0.0
# Mold_Temperature_7                             0.0                       0.0
# Mold_Temperature_8                             0.0                       0.0
# Mold_Temperature_9                             0.0                       0.0
# Mold_Temperature_10                            0.0                       0.0
# Mold_Temperature_11                            0.0                       0.0
# Mold_Temperature_12                            0.0                       0.0
#
#                           ...                      7986  \
# _id                       ...  5fa111cd9c0189cc66daaffe
# TimeStamp                 ...       2020-11-03 08:15:38
# PART_FACT_PLAN_DATE       ...    2020-11-03 오전 12:00:00
# PART_FACT_SERIAL          ...                         7
# PART_NAME                 ...     CN7 W/S SIDE MLD'G RH
# EQUIP_CD                  ...                       S14
# EQUIP_NAME                ...                650톤-우진2호기
# PassOrFail                ...                         Y
# Reason                    ...                      None
# Injection_Time            ...                      9.58
# Filling_Time              ...                      4.46
# Plasticizing_Time         ...                     16.67
# Cycle_Time                ...                     59.52
# Clamp_Close_Time          ...                      7.11
# Cushion_Position          ...                653.429993
# Switch_Over_Position      ...                       0.0
# Plasticizing_Position     ...                 68.339996
# Clamp_Open_Position       ...                 647.98999
# Max_Injection_Speed       ...                 55.200001
# Max_Screw_RPM             ...                      30.6
# Average_Screw_RPM         ...                 29.200001
# Max_Injection_Pressure    ...                142.199997
# Max_Switch_Over_Pressure  ...                136.399994
# Max_Back_Pressure         ...                 37.900002
# Average_Back_Pressure     ...                 59.700001
# Barrel_Temperature_1      ...                275.799988
# Barrel_Temperature_2      ...                     275.5
# Barrel_Temperature_3      ...                     275.5
# Barrel_Temperature_4      ...                     269.5
# Barrel_Temperature_5      ...                     255.0
# Barrel_Temperature_6      ...                230.199997
# Barrel_Temperature_7      ...                       0.0
# Hopper_Temperature        ...                      66.0
# Mold_Temperature_1        ...                       0.0
# Mold_Temperature_2        ...                       0.0
# Mold_Temperature_3        ...                      21.0
# Mold_Temperature_4        ...                      22.4
# Mold_Temperature_5        ...                       0.0
# Mold_Temperature_6        ...                       0.0
# Mold_Temperature_7        ...                       0.0
# Mold_Temperature_8        ...                       0.0
# Mold_Temperature_9        ...                       0.0
# Mold_Temperature_10       ...                       0.0
# Mold_Temperature_11       ...                       0.0
# Mold_Temperature_12       ...                       0.0
#
#                                               7987                      7988  \
# _id                       5fa111ce9c0189cc66dab00f  5fa112129c0189cc66dab52d
# TimeStamp                      2020-11-03 08:15:38       2020-11-03 08:16:38
# PART_FACT_PLAN_DATE         2020-11-03 오전 12:00:00    2020-11-03 오전 12:00:00
# PART_FACT_SERIAL                                 6                         7
# PART_NAME                    CN7 W/S SIDE MLD'G LH     CN7 W/S SIDE MLD'G RH
# EQUIP_CD                                       S14                       S14
# EQUIP_NAME                              650톤-우진2호기                650톤-우진2호기
# PassOrFail                                       Y                         Y
# Reason                                        None                      None
# Injection_Time                                9.58                       9.6
# Filling_Time                                  4.46                      4.49
# Plasticizing_Time                            16.67                     16.65
# Cycle_Time                                   59.52                 59.540001
# Clamp_Close_Time                              7.11                      7.11
# Cushion_Position                        653.429993                653.429993
# Switch_Over_Position                           0.0                       0.0
# Plasticizing_Position                    68.339996                     68.32
# Clamp_Open_Position                      647.98999                 647.98999
# Max_Injection_Speed                      55.200001                 54.900002
# Max_Screw_RPM                                 30.6                 30.799999
# Average_Screw_RPM                        29.200001                 29.200001
# Max_Injection_Pressure                  142.199997                142.100006
# Max_Switch_Over_Pressure                136.399994                136.899994
# Max_Back_Pressure                        37.900002                 38.099998
# Average_Back_Pressure                    59.700001                 59.799999
# Barrel_Temperature_1                    275.799988                276.100006
# Barrel_Temperature_2                         275.5                275.899994
# Barrel_Temperature_3                         275.5                274.899994
# Barrel_Temperature_4                         269.5                269.700012
# Barrel_Temperature_5                         255.0                254.600006
# Barrel_Temperature_6                    230.199997                229.600006
# Barrel_Temperature_7                           0.0                       0.0
# Hopper_Temperature                            66.0                 65.400002
# Mold_Temperature_1                             0.0                       0.0
# Mold_Temperature_2                             0.0                       0.0
# Mold_Temperature_3                            21.0                      21.0
# Mold_Temperature_4                            22.4                      22.4
# Mold_Temperature_5                             0.0                       0.0
# Mold_Temperature_6                             0.0                       0.0
# Mold_Temperature_7                             0.0                       0.0
# Mold_Temperature_8                             0.0                       0.0
# Mold_Temperature_9                             0.0                       0.0
# Mold_Temperature_10                            0.0                       0.0
# Mold_Temperature_11                            0.0                       0.0
# Mold_Temperature_12                            0.0                       0.0
#
#                                               7989                      7990  \
# _id                       5fa112149c0189cc66dab536  5fa112849c0189cc66dabe20
# TimeStamp                      2020-11-03 08:16:38       2020-11-03 08:17:36
# PART_FACT_PLAN_DATE         2020-11-03 오전 12:00:00    2020-11-03 오전 12:00:00
# PART_FACT_SERIAL                                 6                         7
# PART_NAME                    CN7 W/S SIDE MLD'G LH     CN7 W/S SIDE MLD'G RH
# EQUIP_CD                                       S14                       S14
# EQUIP_NAME                              650톤-우진2호기                650톤-우진2호기
# PassOrFail                                       Y                         Y
# Reason                                        None                      None
# Injection_Time                                 9.6                       9.6
# Filling_Time                                  4.49                      4.48
# Plasticizing_Time                            16.65                 16.620001
# Cycle_Time                               59.540001                 59.560001
# Clamp_Close_Time                              7.11                      7.11
# Cushion_Position                        653.429993                653.429993
# Switch_Over_Position                           0.0                       0.0
# Plasticizing_Position                        68.32                 68.330002
# Clamp_Open_Position                      647.98999                 647.98999
# Max_Injection_Speed                      54.900002                 54.900002
# Max_Screw_RPM                            30.799999                 30.700001
# Average_Screw_RPM                        29.200001                 29.200001
# Max_Injection_Pressure                  142.100006                142.100006
# Max_Switch_Over_Pressure                136.899994                     137.0
# Max_Back_Pressure                        38.099998                 38.299999
# Average_Back_Pressure                    59.799999                 59.900002
# Barrel_Temperature_1                    276.100006                     276.5
# Barrel_Temperature_2                    275.899994                274.899994
# Barrel_Temperature_3                    274.899994                275.100006
# Barrel_Temperature_4                    269.700012                     269.5
# Barrel_Temperature_5                    254.600006                255.600006
# Barrel_Temperature_6                    229.600006                229.600006
# Barrel_Temperature_7                           0.0                       0.0
# Hopper_Temperature                       65.400002                 66.099998
# Mold_Temperature_1                             0.0                       0.0
# Mold_Temperature_2                             0.0                       0.0
# Mold_Temperature_3                            21.0                      21.0
# Mold_Temperature_4                            22.4                      22.4
# Mold_Temperature_5                             0.0                       0.0
# Mold_Temperature_6                             0.0                       0.0
# Mold_Temperature_7                             0.0                       0.0
# Mold_Temperature_8                             0.0                       0.0
# Mold_Temperature_9                             0.0                       0.0
# Mold_Temperature_10                            0.0                       0.0
# Mold_Temperature_11                            0.0                       0.0
# Mold_Temperature_12                            0.0                       0.0
#
#                                               7991                      7992  \
# _id                       5fa112859c0189cc66dabe34  5fa112869c0189cc66dabe42
# TimeStamp                      2020-11-03 08:17:36       2020-11-03 08:18:37
# PART_FACT_PLAN_DATE         2020-11-03 오전 12:00:00    2020-11-03 오전 12:00:00
# PART_FACT_SERIAL                                 6                         7
# PART_NAME                    CN7 W/S SIDE MLD'G LH     CN7 W/S SIDE MLD'G RH
# EQUIP_CD                                       S14                       S14
# EQUIP_NAME                              650톤-우진2호기                650톤-우진2호기
# PassOrFail                                       Y                         Y
# Reason                                        None                      None
# Injection_Time                                 9.6                       9.6
# Filling_Time                                  4.48                      4.48
# Plasticizing_Time                        16.620001                     16.65
# Cycle_Time                               59.560001                 59.560001
# Clamp_Close_Time                              7.11                      7.11
# Cushion_Position                        653.429993                653.429993
# Switch_Over_Position                           0.0                       0.0
# Plasticizing_Position                    68.330002                 68.349998
# Clamp_Open_Position                      647.98999                 647.98999
# Max_Injection_Speed                      54.900002                      55.0
# Max_Screw_RPM                            30.700001                 30.700001
# Average_Screw_RPM                        29.200001                 29.200001
# Max_Injection_Pressure                  142.100006                142.100006
# Max_Switch_Over_Pressure                     137.0                136.800003
# Max_Back_Pressure                        38.299999                 38.400002
# Average_Back_Pressure                    59.900002                 59.900002
# Barrel_Temperature_1                         276.5                275.799988
# Barrel_Temperature_2                    274.899994                275.299988
# Barrel_Temperature_3                    275.100006                     275.5
# Barrel_Temperature_4                         269.5                270.700012
# Barrel_Temperature_5                    255.600006                254.899994
# Barrel_Temperature_6                    229.600006                     230.0
# Barrel_Temperature_7                           0.0                       0.0
# Hopper_Temperature                       66.099998                 66.099998
# Mold_Temperature_1                             0.0                       0.0
# Mold_Temperature_2                             0.0                       0.0
# Mold_Temperature_3                            21.0                      21.0
# Mold_Temperature_4                            22.4                      22.4
# Mold_Temperature_5                             0.0                       0.0
# Mold_Temperature_6                             0.0                       0.0
# Mold_Temperature_7                             0.0                       0.0
# Mold_Temperature_8                             0.0                       0.0
# Mold_Temperature_9                             0.0                       0.0
# Mold_Temperature_10                            0.0                       0.0
# Mold_Temperature_11                            0.0                       0.0
# Mold_Temperature_12                            0.0                       0.0
#
#                                               7993                      7994  \
# _id                       5fa112879c0189cc66dabe50  5fa112bb9c0189cc66dac22a
# TimeStamp                      2020-11-03 08:18:37       2020-11-03 08:19:35
# PART_FACT_PLAN_DATE         2020-11-03 오전 12:00:00    2020-11-03 오전 12:00:00
# PART_FACT_SERIAL                                 6                         6
# PART_NAME                    CN7 W/S SIDE MLD'G LH     CN7 W/S SIDE MLD'G LH
# EQUIP_CD                                       S14                       S14
# EQUIP_NAME                              650톤-우진2호기                650톤-우진2호기
# PassOrFail                                       Y                         Y
# Reason                                        None                      None
# Injection_Time                                 9.6                       9.6
# Filling_Time                                  4.48                      4.48
# Plasticizing_Time                            16.65                 16.629999
# Cycle_Time                               59.560001                 59.580002
# Clamp_Close_Time                              7.11                      7.11
# Cushion_Position                        653.429993                653.429993
# Switch_Over_Position                           0.0                       0.0
# Plasticizing_Position                    68.349998                 68.330002
# Clamp_Open_Position                      647.98999                 647.98999
# Max_Injection_Speed                           55.0                 54.900002
# Max_Screw_RPM                            30.700001                 30.700001
# Average_Screw_RPM                        29.200001                 29.200001
# Max_Injection_Pressure                  142.100006                142.100006
# Max_Switch_Over_Pressure                136.800003                136.899994
# Max_Back_Pressure                        38.400002                 38.400002
# Average_Back_Pressure                    59.900002                 59.900002
# Barrel_Temperature_1                    275.799988                276.100006
# Barrel_Temperature_2                    275.299988                275.799988
# Barrel_Temperature_3                         275.5                     275.0
# Barrel_Temperature_4                    270.700012                271.299988
# Barrel_Temperature_5                    254.899994                255.100006
# Barrel_Temperature_6                         230.0                230.199997
# Barrel_Temperature_7                           0.0                       0.0
# Hopper_Temperature                       66.099998                 65.199997
# Mold_Temperature_1                             0.0                       0.0
# Mold_Temperature_2                             0.0                       0.0
# Mold_Temperature_3                            21.0                      21.0
# Mold_Temperature_4                            22.4                 22.299999
# Mold_Temperature_5                             0.0                       0.0
# Mold_Temperature_6                             0.0                       0.0
# Mold_Temperature_7                             0.0                       0.0
# Mold_Temperature_8                             0.0                       0.0
# Mold_Temperature_9                             0.0                       0.0
# Mold_Temperature_10                            0.0                       0.0
# Mold_Temperature_11                            0.0                       0.0
# Mold_Temperature_12                            0.0                       0.0
#
#                                               7995
# _id                       5fa112bc9c0189cc66dac23a
# TimeStamp                      2020-11-03 08:19:35
# PART_FACT_PLAN_DATE         2020-11-03 오전 12:00:00
# PART_FACT_SERIAL                                 7
# PART_NAME                    CN7 W/S SIDE MLD'G RH
# EQUIP_CD                                       S14
# EQUIP_NAME                              650톤-우진2호기
# PassOrFail                                       Y
# Reason                                        None
# Injection_Time                                 9.6
# Filling_Time                                  4.48
# Plasticizing_Time                        16.629999
# Cycle_Time                               59.580002
# Clamp_Close_Time                              7.11
# Cushion_Position                        653.429993
# Switch_Over_Position                           0.0
# Plasticizing_Position                    68.330002
# Clamp_Open_Position                      647.98999
# Max_Injection_Speed                      54.900002
# Max_Screw_RPM                            30.700001
# Average_Screw_RPM                        29.200001
# Max_Injection_Pressure                  142.100006
# Max_Switch_Over_Pressure                136.899994
# Max_Back_Pressure                        38.400002
# Average_Back_Pressure                    59.900002
# Barrel_Temperature_1                    276.100006
# Barrel_Temperature_2                    275.799988
# Barrel_Temperature_3                         275.0
# Barrel_Temperature_4                    271.299988
# Barrel_Temperature_5                    255.100006
# Barrel_Temperature_6                    230.199997
# Barrel_Temperature_7                           0.0
# Hopper_Temperature                       65.199997
# Mold_Temperature_1                             0.0
# Mold_Temperature_2                             0.0
# Mold_Temperature_3                            21.0
# Mold_Temperature_4                       22.299999
# Mold_Temperature_5                             0.0
# Mold_Temperature_6                             0.0
# Mold_Temperature_7                             0.0
# Mold_Temperature_8                             0.0
# Mold_Temperature_9                             0.0
# Mold_Temperature_10                            0.0
# Mold_Temperature_11                            0.0
# Mold_Temperature_12                            0.0
#
# [45 rows x 7996 columns]

# %%
#PART_NAME => 제품의 이름
#EQUIP_CD => unlabeled_data => 생산한 사출기 호기
#EQUIP_NAME => 생산한 사출기 이름

labeled_data['PART_NAME'].value_counts() #cn7 ~ rg3 데이터 사용
labeled_data['PART_NAME'].value_counts()
# Out:
# CN7 W/S SIDE MLD'G RH        3371
# CN7 W/S SIDE MLD'G LH        3365
# RG3 MOLD'G W/SHLD, LH         628
# RG3 MOLD'G W/SHLD, RH         628
# SP2 CVR ROOF RACK CTR, RH       2
# JX1 W/S SIDE MLD'G RH           2
# Name: PART_NAME, dtype: int64

# %%
labeled_data['EQUIP_NAME'].value_counts() #650톤 -우진2호기만 사용
# Out:
# 650톤-우진2호기    7992
# 1800TON-우진       2
# 650톤-우진          2
# Name: EQUIP_NAME, dtype: int64

# %%
labeled_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7996 entries, 0 to 7995
# Data columns (total 45 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   _id                       7996 non-null   object
#  1   TimeStamp                 7996 non-null   object
#  2   PART_FACT_PLAN_DATE       7996 non-null   object
#  3   PART_FACT_SERIAL          7996 non-null   int64
#  4   PART_NAME                 7996 non-null   object
#  5   EQUIP_CD                  7996 non-null   object
#  6   EQUIP_NAME                7996 non-null   object
#  7   PassOrFail                7996 non-null   object
#  8   Reason                    7996 non-null   object
#  9   Injection_Time            7996 non-null   float64
#  10  Filling_Time              7996 non-null   float64
#  11  Plasticizing_Time         7996 non-null   float64
#  12  Cycle_Time                7996 non-null   float64
#  13  Clamp_Close_Time          7996 non-null   float64
#  14  Cushion_Position          7996 non-null   float64
#  15  Switch_Over_Position      7996 non-null   float64
#  16  Plasticizing_Position     7996 non-null   float64
#  17  Clamp_Open_Position       7996 non-null   float64
#  18  Max_Injection_Speed       7996 non-null   float64
#  19  Max_Screw_RPM             7996 non-null   float64
#  20  Average_Screw_RPM         7996 non-null   float64
#  21  Max_Injection_Pressure    7996 non-null   float64
#  22  Max_Switch_Over_Pressure  7996 non-null   float64
#  23  Max_Back_Pressure         7996 non-null   float64
#  24  Average_Back_Pressure     7996 non-null   float64
#  25  Barrel_Temperature_1      7996 non-null   float64
#  26  Barrel_Temperature_2      7996 non-null   float64
#  27  Barrel_Temperature_3      7996 non-null   float64
#  28  Barrel_Temperature_4      7996 non-null   float64
#  29  Barrel_Temperature_5      7996 non-null   float64
#  30  Barrel_Temperature_6      7996 non-null   float64
#  31  Barrel_Temperature_7      7996 non-null   float64
#  32  Hopper_Temperature        7996 non-null   float64
#  33  Mold_Temperature_1        7996 non-null   float64
#  34  Mold_Temperature_2        7996 non-null   float64
#  35  Mold_Temperature_3        7996 non-null   float64
#  36  Mold_Temperature_4        7996 non-null   float64
#  37  Mold_Temperature_5        7996 non-null   float64
#  38  Mold_Temperature_6        7996 non-null   float64
#  39  Mold_Temperature_7        7996 non-null   float64
#  40  Mold_Temperature_8        7996 non-null   float64
#  41  Mold_Temperature_9        7996 non-null   float64
#  42  Mold_Temperature_10       7996 non-null   float64
#  43  Mold_Temperature_11       7996 non-null   float64
#  44  Mold_Temperature_12       7996 non-null   float64
# dtypes: float64(36), int64(1), object(8)
# memory usage: 2.7+ MB

# %%
#사출기 이름 : 650톤 -우진2호기, => 사출기 이름
#PART_NAME : 
#CN7 W/S SIDE MLD'G RH, CN7 W/S SIDE MLD'G LH, RG3 MOLD'G W/SHLD, LH,RG3 MOLD'G W/SHLD, RH => 제품의 이름

equip_ = '650톤-우진2호기'
labeled_data = labeled_data[labeled_data['EQUIP_NAME'] == equip_]

# %%
labeled_data.drop(['_id','TimeStamp','PART_FACT_PLAN_DATE','PART_FACT_SERIAL','EQUIP_CD','EQUIP_NAME','Reason',
                   'Mold_Temperature_1','Mold_Temperature_2','Mold_Temperature_5','Mold_Temperature_6','Mold_Temperature_7',
                   'Mold_Temperature_8','Mold_Temperature_9','Mold_Temperature_10','Mold_Temperature_11','Mold_Temperature_12','Switch_Over_Position',
                   'Barrel_Temperature_7'],
                  axis = 1, inplace = True)

# %%
product_ = ["CN7 W/S SIDE MLD'G RH","CN7 W/S SIDE MLD'G LH","RG3 MOLD'G W/SHLD, LH","RG3 MOLD'G W/SHLD, RH"]

labeled_data_cn7rh = labeled_data[labeled_data['PART_NAME'] == product_[0]]
labeled_data_cn7lh = labeled_data[labeled_data['PART_NAME'] == product_[1]]
labeled_data_rg3lh = labeled_data[labeled_data['PART_NAME'] == product_[2]]
labeled_data_rg3rh = labeled_data[labeled_data['PART_NAME'] == product_[3]]

# %%
labeled_data_cn7rh.drop(['PART_NAME'], axis = 1, inplace = True)
labeled_data_cn7lh.drop(['PART_NAME'], axis = 1, inplace = True)
labeled_data_rg3lh.drop(['PART_NAME'], axis = 1, inplace = True)
labeled_data_rg3rh.drop(['PART_NAME'], axis = 1, inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
cn7_labeled = pd.concat([labeled_data_cn7rh,labeled_data_cn7lh], ignore_index = True) #cn7 제품
rg3_labeled = pd.concat([labeled_data_rg3lh,labeled_data_rg3rh], ignore_index = True) #rg3 제품

# %% [markdown]
# # 3. 데이터 NUll 값 및 outlier 제거

# %% [markdown]
# ## 3.1 종속 변수와 상관관계가 높은 변수 선정

# %%
#PassOrFail : 양품 or 정상
#양품(y) -> 0
#불량(n) -> 1

labeled_data['PassOrFail'].unique()
cn7_labeled['PassOrFail'].replace({'Y':0,'N' : 1}, inplace = True)
rg3_labeled['PassOrFail'].replace({'Y':0,'N' : 1}, inplace = True)

# %%
#cn7 제품 features 들간의 상관관계
#대략 확인한 종속변수와 관계가 깊은 변수 Filling_Time, Injection_Time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize = (25,25))
sns.heatmap(cn7_labeled.corr(), annot = True, fmt = '.2f', cmap = 'Blues')

# %%
#rg3 제품 features 들간의 상관관계
#딱히 종속변수에 높아보이는 변수 존재 x
plt.figure(figsize = (25,25))
sns.heatmap(rg3_labeled.corr(), annot = True, fmt = '.2f', cmap = 'Blues')

# %% [markdown]
# ## 3.2 종속 변수와 상관 관계 높은(그나마) 변수 outlier 확인

# %%
plt.figure(figsize = (15,4))
plt.boxplot(cn7_labeled['Filling_Time'])
plt.figure(figsize = (15,4))
plt.boxplot(cn7_labeled['Injection_Time'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f8562903090>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f8562924590>,
#   <matplotlib.lines.Line2D at 0x7f8562c6fe10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f85628cda90>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f85628cd550>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f8562924b10>,
#   <matplotlib.lines.Line2D at 0x7f8562924f10>]}

# %%
import numpy as np

def outlier_iqr(data):
  q1, q3 = np.percentile(data, [25,75])

  iqr = q3 - q1
  lower_bound = q1 - (iqr * 1.5)
  upper_bound = q3 + (iqr * 1.5)

  return np.where((data > upper_bound) | (data < lower_bound))

# %%
ch7_filling_time_outlier_idx = outlier_iqr(cn7_labeled['Filling_Time'])[0]
ch7_injection_time_outlier_idx = outlier_iqr(cn7_labeled['Injection_Time'])[0]

# %%
#이상치 제외하고 평균 값 측정 후, 이상치 값들을 평균 값으로 대체

#Filling time
cn7_labeled.drop(ch7_filling_time_outlier_idx, axis = 0)['Filling_Time'].mean()
cn7_labeled.loc[ch7_filling_time_outlier_idx, 'Filling_Time'] = 4.45

#Injection time
cn7_labeled.drop(ch7_injection_time_outlier_idx, axis = 0)['Injection_Time'].mean()
cn7_labeled.loc[ch7_injection_time_outlier_idx, 'Injection_Time'] = 9.56

# %%
#이상치 제거 후 boxplot 확인

plt.figure(figsize = (15,4))
plt.boxplot(cn7_labeled['Filling_Time'])
plt.figure(figsize = (15,4))
plt.boxplot(cn7_labeled['Injection_Time'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f8562153490>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f85621594d0>,
#   <matplotlib.lines.Line2D at 0x7f8562159a10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f856215f510>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f8562159f90>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f8562153a10>,
#   <matplotlib.lines.Line2D at 0x7f8562153f50>]}

# %% [markdown]
# ## 3.3 NULL 값 확인

# %%
#cn7_labeled null 값 확인

cn7_labeled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6736 entries, 0 to 6735
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   PassOrFail                6736 non-null   int64
#  1   Injection_Time            6736 non-null   float64
#  2   Filling_Time              6736 non-null   float64
#  3   Plasticizing_Time         6736 non-null   float64
#  4   Cycle_Time                6736 non-null   float64
#  5   Clamp_Close_Time          6736 non-null   float64
#  6   Cushion_Position          6736 non-null   float64
#  7   Plasticizing_Position     6736 non-null   float64
#  8   Clamp_Open_Position       6736 non-null   float64
#  9   Max_Injection_Speed       6736 non-null   float64
#  10  Max_Screw_RPM             6736 non-null   float64
#  11  Average_Screw_RPM         6736 non-null   float64
#  12  Max_Injection_Pressure    6736 non-null   float64
#  13  Max_Switch_Over_Pressure  6736 non-null   float64
#  14  Max_Back_Pressure         6736 non-null   float64
#  15  Average_Back_Pressure     6736 non-null   float64
#  16  Barrel_Temperature_1      6736 non-null   float64
#  17  Barrel_Temperature_2      6736 non-null   float64
#  18  Barrel_Temperature_3      6736 non-null   float64
#  19  Barrel_Temperature_4      6736 non-null   float64
#  20  Barrel_Temperature_5      6736 non-null   float64
#  21  Barrel_Temperature_6      6736 non-null   float64
#  22  Hopper_Temperature        6736 non-null   float64
#  23  Mold_Temperature_3        6736 non-null   float64
#  24  Mold_Temperature_4        6736 non-null   float64
# dtypes: float64(24), int64(1)
# memory usage: 1.3 MB

# %%
import missingno as msno

msno.matrix(cn7_labeled)

# %%
#rg3_labeled null 값 확인 
rg3_labeled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1256 entries, 0 to 1255
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   PassOrFail                1256 non-null   int64
#  1   Injection_Time            1256 non-null   float64
#  2   Filling_Time              1256 non-null   float64
#  3   Plasticizing_Time         1256 non-null   float64
#  4   Cycle_Time                1256 non-null   float64
#  5   Clamp_Close_Time          1256 non-null   float64
#  6   Cushion_Position          1256 non-null   float64
#  7   Plasticizing_Position     1256 non-null   float64
#  8   Clamp_Open_Position       1256 non-null   float64
#  9   Max_Injection_Speed       1256 non-null   float64
#  10  Max_Screw_RPM             1256 non-null   float64
#  11  Average_Screw_RPM         1256 non-null   float64
#  12  Max_Injection_Pressure    1256 non-null   float64
#  13  Max_Switch_Over_Pressure  1256 non-null   float64
#  14  Max_Back_Pressure         1256 non-null   float64
#  15  Average_Back_Pressure     1256 non-null   float64
#  16  Barrel_Temperature_1      1256 non-null   float64
#  17  Barrel_Temperature_2      1256 non-null   float64
#  18  Barrel_Temperature_3      1256 non-null   float64
#  19  Barrel_Temperature_4      1256 non-null   float64
#  20  Barrel_Temperature_5      1256 non-null   float64
#  21  Barrel_Temperature_6      1256 non-null   float64
#  22  Hopper_Temperature        1256 non-null   float64
#  23  Mold_Temperature_3        1256 non-null   float64
#  24  Mold_Temperature_4        1256 non-null   float64
# dtypes: float64(24), int64(1)
# memory usage: 245.4 KB

# %%
msno.matrix(rg3_labeled)

# %% [markdown]
# ## ver2 expected purpose
# - moldset_labeled.csv 데이터 전처리
#   - 종속변수와 상관관계 높은 변수 선정하여 outlier 및 null 값 제거(다 확인 힘드니)
#   - 데이터 값이 이상한 변수 삭제
#   - 종속변수 label 숫자로 변환

# %% [markdown]
# # 그 이외 데이터 잠시 살펴보기

# %%
#unlabeled Data info 확인
#변수 null값 및 data type 확인

unlabeled_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 795315 entries, 0 to 795314
# Data columns (total 46 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Unnamed: 0                795315 non-null  int64
#  1   _id                       795315 non-null  object
#  2   TimeStamp                 795315 non-null  object
#  3   PART_FACT_PLAN_DATE       795315 non-null  object
#  4   PART_FACT_SERIAL          795315 non-null  int64
#  5   PART_NO                   795315 non-null  object
#  6   PART_NAME                 795315 non-null  object
#  7   EQUIP_CD                  795315 non-null  object
#  8   EQUIP_NAME                795315 non-null  object
#  9   ERR_FACT_QTY              795315 non-null  int64
#  10  Injection_Time            795315 non-null  float64
#  11  Filling_Time              795315 non-null  float64
#  12  Plasticizing_Time         795315 non-null  float64
#  13  Cycle_Time                795315 non-null  float64
#  14  Clamp_Close_Time          795315 non-null  float64
#  15  Cushion_Position          795315 non-null  float64
#  16  Switch_Over_Position      795315 non-null  float64
#  17  Plasticizing_Position     795315 non-null  float64
#  18  Clamp_Open_Position       795315 non-null  float64
#  19  Max_Injection_Speed       795315 non-null  float64
#  20  Max_Screw_RPM             795315 non-null  float64
#  21  Average_Screw_RPM         795315 non-null  float64
#  22  Max_Injection_Pressure    795315 non-null  float64
#  23  Max_Switch_Over_Pressure  795315 non-null  float64
#  24  Max_Back_Pressure         795315 non-null  float64
#  25  Average_Back_Pressure     795315 non-null  float64
#  26  Barrel_Temperature_1      795315 non-null  float64
#  27  Barrel_Temperature_2      795315 non-null  float64
#  28  Barrel_Temperature_3      795315 non-null  float64
#  29  Barrel_Temperature_4      795315 non-null  float64
#  30  Barrel_Temperature_5      795315 non-null  float64
#  31  Barrel_Temperature_6      795315 non-null  float64
#  32  Barrel_Temperature_7      795315 non-null  float64
#  33  Hopper_Temperature        795315 non-null  float64
#  34  Mold_Temperature_1        795315 non-null  int64
#  35  Mold_Temperature_2        795315 non-null  int64
#  36  Mold_Temperature_3        795315 non-null  float64
#  37  Mold_Temperature_4        795315 non-null  float64
#  38  Mold_Temperature_5        795315 non-null  int64
#  39  Mold_Temperature_6        795315 non-null  int64
#  40  Mold_Temperature_7        795315 non-null  int64
#  41  Mold_Temperature_8        795315 non-null  int64
#  42  Mold_Temperature_9        795315 non-null  int64
#  43  Mold_Temperature_10       795315 non-null  int64
#  44  Mold_Temperature_11       795315 non-null  int64
#  45  Mold_Temperature_12       795315 non-null  int64
# dtypes: float64(26), int64(13), object(7)
# memory usage: 279.1+ MB

# %%
#labeled data 기술 통계 수치 확인
#이상 변수들 탐지
labeled_data.describe().T
# Out:
#                            count         mean         std         min  \
# Unnamed: 0                2607.0  1303.000000  752.720400    0.000000
# PART_FACT_SERIAL          2607.0    13.431914    4.572502    9.000000
# PassOrFail                2607.0     0.019946    0.139843    0.000000
# Injection_Time            2607.0     5.711105    4.238696    1.050000
# Filling_Time              2607.0     2.858807    1.756242    0.930000
# Plasticizing_Time         2607.0    15.139693    2.026422   12.800000
# Cycle_Time                2607.0    60.542800    1.125377   58.959999
# Clamp_Close_Time          2607.0     6.978470    0.160223    6.790000
# Cushion_Position          2607.0   653.797856    0.415763  653.390015
# Switch_Over_Position      2607.0     1.005462   25.654063    0.000000
# Plasticizing_Position     2607.0    61.788588    7.476050   53.549999
# Clamp_Open_Position       2607.0   356.293976  320.340979    4.630000
# Max_Injection_Speed       2607.0    88.637821   36.066344   38.500000
# Max_Screw_RPM             2607.0    30.803644    0.121917   30.400000
# Average_Screw_RPM         2607.0   291.602110    0.982286  290.399994
# Max_Injection_Pressure    2607.0   142.180591    0.477875  140.699997
# Max_Switch_Over_Pressure  2607.0   127.334331   10.100797  109.699997
# Max_Back_Pressure         2607.0    46.179670    9.039279   36.299999
# Average_Back_Pressure     2607.0    60.133602    1.097058   57.700001
# Barrel_Temperature_1      2607.0   280.603644    4.897553  274.799988
# Barrel_Temperature_2      2607.0   279.777023    4.959188  274.200012
# Barrel_Temperature_3      2607.0   279.534331    4.989901  274.100006
# Barrel_Temperature_4      2607.0   272.657615    2.579055  268.799988
# Barrel_Temperature_5      2607.0   259.536862    4.996041  253.500000
# Barrel_Temperature_6      2607.0   232.249981    2.488097  229.300003
# Barrel_Temperature_7      2607.0     0.000000    0.000000    0.000000
# Hopper_Temperature        2607.0    66.722401    1.586983   62.599998
# Mold_Temperature_1        2607.0     0.000000    0.000000    0.000000
# Mold_Temperature_2        2607.0     0.000000    0.000000    0.000000
# Mold_Temperature_3        2607.0    22.808362    1.274660   19.600000
# Mold_Temperature_4        2607.0    24.184312    1.686676   21.000000
# Mold_Temperature_5        2607.0     0.000000    0.000000    0.000000
# Mold_Temperature_6        2607.0     0.000000    0.000000    0.000000
# Mold_Temperature_7        2607.0     0.000000    0.000000    0.000000
# Mold_Temperature_8        2607.0     0.000000    0.000000    0.000000
# Mold_Temperature_9        2607.0     0.000000    0.000000    0.000000
# Mold_Temperature_10       2607.0     0.000000    0.000000    0.000000
# Mold_Temperature_11       2607.0     0.000000    0.000000    0.000000
# Mold_Temperature_12       2607.0     0.000000    0.000000    0.000000
#
#                                  25%          50%          75%          max
# Unnamed: 0                651.500000  1303.000000  1954.500000  2606.000000
# PART_FACT_SERIAL           10.000000    12.000000    14.000000    24.000000
# PassOrFail                  0.000000     0.000000     0.000000     1.000000
# Injection_Time              1.060000     9.520000     9.550000    13.390000
# Filling_Time                0.940000     4.410000     4.440000     8.270000
# Plasticizing_Time          12.920000    16.780001    17.000000    21.100000
# Cycle_Time                 59.520000    59.580002    61.779999    62.360001
# Clamp_Close_Time            6.800000     7.120000     7.120000     7.180000
# Cushion_Position          653.409973   653.450012   654.250000   654.289978
# Switch_Over_Position        0.000000     0.000000     0.000000   655.309998
# Plasticizing_Position      53.590000    68.480003    68.500000    68.860001
# Clamp_Open_Position         4.630000   647.989990   647.989990   647.989990
# Max_Injection_Speed        55.900002    56.299999   128.199997   128.500000
# Max_Screw_RPM              30.700001    30.799999    30.900000    31.200001
# Average_Screw_RPM         290.500000   292.399994   292.500000   293.899994
# Max_Injection_Pressure    141.800003   142.199997   142.600006   147.399994
# Max_Switch_Over_Pressure  116.300003   136.000000   136.500000   146.699997
# Max_Back_Pressure          38.099998    38.599998    56.000000    71.900002
# Average_Back_Pressure      59.500000    59.799999    60.799999    87.099998
# Barrel_Temperature_1      276.100006   276.799988   285.899994   287.100006
# Barrel_Temperature_2      275.299988   275.700012   285.100006   286.500000
# Barrel_Temperature_3      275.000000   275.500000   285.000000   285.799988
# Barrel_Temperature_4      270.299988   271.500000   275.299988   276.799988
# Barrel_Temperature_5      255.000000   255.399994   265.000000   266.399994
# Barrel_Temperature_6      230.000000   230.300003   235.000000   235.500000
# Barrel_Temperature_7        0.000000     0.000000     0.000000     0.000000
# Hopper_Temperature         65.500000    66.599998    67.699997    70.599998
# Mold_Temperature_1          0.000000     0.000000     0.000000     0.000000
# Mold_Temperature_2          0.000000     0.000000     0.000000     0.000000
# Mold_Temperature_3         21.900000    22.799999    23.600000    25.299999
# Mold_Temperature_4         23.100000    23.799999    24.799999    27.799999
# Mold_Temperature_5          0.000000     0.000000     0.000000     0.000000
# Mold_Temperature_6          0.000000     0.000000     0.000000     0.000000
# Mold_Temperature_7          0.000000     0.000000     0.000000     0.000000
# Mold_Temperature_8          0.000000     0.000000     0.000000     0.000000
# Mold_Temperature_9          0.000000     0.000000     0.000000     0.000000
# Mold_Temperature_10         0.000000     0.000000     0.000000     0.000000
# Mold_Temperature_11         0.000000     0.000000     0.000000     0.000000
# Mold_Temperature_12         0.000000     0.000000     0.000000     0.000000

# %%
#unlabeled data 기술 통계 수치 확인
#이상 변수들 탐지
unlabeled_data.describe().T
# Out:
#                              count           mean            std     min  \
# Unnamed: 0                795315.0  397657.000000  229587.809007    0.00
# PART_FACT_SERIAL          795315.0       7.346591       6.070685    1.00
# ERR_FACT_QTY              795315.0      13.862124      26.549459    0.00
# Injection_Time            795315.0       9.454754       5.569126    0.13
# Filling_Time              795315.0       3.897417       1.645200    0.00
# Plasticizing_Time         795315.0      11.230021       7.619902    0.20
# Cycle_Time                795315.0      58.030807      16.916262    0.00
# Clamp_Close_Time          795315.0       5.575053       1.913712    2.11
# Cushion_Position          795315.0     215.040085     296.933993    0.00
# Switch_Over_Position      795315.0      10.884156      19.045073    0.00
# Plasticizing_Position     795315.0      63.556493      40.963720   31.27
# Clamp_Open_Position       795315.0     561.095939     369.229806    0.00
# Max_Injection_Speed       795315.0      47.579900      27.673404    0.00
# Max_Screw_RPM             795315.0      22.219916      18.474614    0.00
# Average_Screw_RPM         795315.0     104.958686     132.135577    0.00
# Max_Injection_Pressure    795315.0     118.592751      34.728643    0.00
# Max_Switch_Over_Pressure  795315.0     101.215787      31.695158    0.10
# Max_Back_Pressure         795315.0      15.499801      20.118355    0.00
# Average_Back_Pressure     795315.0      27.840412      28.318217    0.00
# Barrel_Temperature_1      795315.0      88.723012     124.626114    0.00
# Barrel_Temperature_2      795315.0     262.881242      13.272051  189.40
# Barrel_Temperature_3      795315.0     266.185574      11.712932  189.00
# Barrel_Temperature_4      795315.0     264.326963      11.421668  179.40
# Barrel_Temperature_5      795315.0     257.662214      12.901731  179.60
# Barrel_Temperature_6      795315.0     241.974084      15.345906  167.80
# Barrel_Temperature_7      795315.0      22.456352      15.800926    0.00
# Hopper_Temperature        795315.0      38.443004      27.358290    0.00
# Mold_Temperature_1        795315.0       0.000000       0.000000    0.00
# Mold_Temperature_2        795315.0       0.000000       0.000000    0.00
# Mold_Temperature_3        795315.0       7.672545      11.476776    0.00
# Mold_Temperature_4        795315.0       8.939656      13.608882    0.00
# Mold_Temperature_5        795315.0       0.000000       0.000000    0.00
# Mold_Temperature_6        795315.0       0.000000       0.000000    0.00
# Mold_Temperature_7        795315.0       0.000000       0.000000    0.00
# Mold_Temperature_8        795315.0       0.000000       0.000000    0.00
# Mold_Temperature_9        795315.0       0.000000       0.000000    0.00
# Mold_Temperature_10       795315.0       0.000000       0.000000    0.00
# Mold_Temperature_11       795315.0       0.000000       0.000000    0.00
# Mold_Temperature_12       795315.0       0.000000       0.000000    0.00
#
#                                 25%        50%        75%        max
# Unnamed: 0                198828.50  397657.00  596485.50  795314.00
# PART_FACT_SERIAL               2.00       6.00      10.00      54.00
# ERR_FACT_QTY                   1.00       5.00      13.00     353.00
# Injection_Time                 5.00       9.52      16.29      29.10
# Filling_Time                   2.95       3.35       5.00      29.10
# Plasticizing_Time              2.90      10.95      16.77     468.20
# Cycle_Time                    39.10      64.42      67.59     648.39
# Clamp_Close_Time               3.40       6.08       6.72      30.10
# Cushion_Position              11.80      18.20     653.62     655.33
# Switch_Over_Position           0.00      10.00      18.20     655.34
# Plasticizing_Position         40.50      59.90      63.42     392.90
# Clamp_Open_Position          485.60     522.50     883.30    1901.00
# Max_Injection_Speed           25.70      38.80      55.90     128.80
# Max_Screw_RPM                  0.00      27.00      30.70     106.30
# Average_Screw_RPM              0.00      25.50     290.60     484.20
# Max_Injection_Pressure        80.70     131.70     141.70     199.90
# Max_Switch_Over_Pressure      70.00     102.30     131.90    6553.10
# Max_Back_Pressure              3.80       5.20      17.80     121.50
# Average_Back_Pressure          0.00      22.10      49.30     165.20
# Barrel_Temperature_1           0.00       0.00     245.30     990.20
# Barrel_Temperature_2         260.40     264.80     265.90     340.30
# Barrel_Temperature_3         264.90     269.90     270.40     290.30
# Barrel_Temperature_4         264.80     269.80     270.10     290.10
# Barrel_Temperature_5         254.80     259.90     269.80     290.20
# Barrel_Temperature_6         230.10     239.90     259.80     276.80
# Barrel_Temperature_7           0.00      30.20      32.80      50.50
# Hopper_Temperature             0.00      56.70      61.60      75.10
# Mold_Temperature_1             0.00       0.00       0.00       0.00
# Mold_Temperature_2             0.00       0.00       0.00       0.00
# Mold_Temperature_3             0.00       0.00      20.70      39.20
# Mold_Temperature_4             0.00       0.00      23.30      51.10
# Mold_Temperature_5             0.00       0.00       0.00       0.00
# Mold_Temperature_6             0.00       0.00       0.00       0.00
# Mold_Temperature_7             0.00       0.00       0.00       0.00
# Mold_Temperature_8             0.00       0.00       0.00       0.00
# Mold_Temperature_9             0.00       0.00       0.00       0.00
# Mold_Temperature_10            0.00       0.00       0.00       0.00
# Mold_Temperature_11            0.00       0.00       0.00       0.00
# Mold_Temperature_12            0.00       0.00       0.00       0.00

# %% [markdown]
# ## 2.2 이상 변수 제거
# - 기술 통계 수치가 0을 기록하고 있는 변수들 제거.
# - 의미상 필요하지 않은 변수 제거.

# %%
#데이터 간략 확인


#EQUIP_CD 확인
labeled_data.head().T
labeled_data['EQUIP_CD'].unique() #Only S14
unlabeled_data['EQUIP_CD'].unique() #S01,04,06,10,02,11,12,07,13,09,14,15,08
# Out:
# array(['S01', 'S04', 'S06', 'S10', 'S02', 'S11', 'S12', 'S07', 'S13',
#        'S09', 'S14', 'S15', 'S08'], dtype=object)

# %%
#Reason 확인
labeled_data['Reason'].value_counts()
# Out:
# None      2555
# 가스          30
# 미성형         12
# 초기허용불량      10
# Name: Reason, dtype: int64

# %%
#PART_NAME 확인

labeled_data['PART_NAME'].value_counts()
# Out:
# CN7 W/S SIDE MLD'G RH    713
# CN7 W/S SIDE MLD'G LH    712
# RG3 MOLD'G W/SHLD, LH    591
# RG3 MOLD'G W/SHLD, RH    591
# Name: PART_NAME, dtype: int64

# %%
#EQUIP_NAME

labeled_data['EQUIP_NAME'].value_counts()
# Out:
# 650톤-우진2호기    2607
# Name: EQUIP_NAME, dtype: int64

# %%
#Labeled Drop List _1
#'Unnamed: 0','_id','TimeStamp','PART_FACT_PLAN_DATE' : 분석에 필요하지 않은 데이터라고 판단
#PART_NAME : PART_NO 로 이미 구분 가능하기 때문에 삭제
#EQUIP_CD : labeled_data 의 경우 CD value 가 single 이다.(S14)
#Reason : Unlabeled 된 경우가 많음
#Mold_Temperature Series, Barrel_Temperature_7, Switch_Over_Position: 데이터가 대부분 0인 경우가 많음
#EQUIP_NAME : value 가 single 임

drop_labeled_features = ['Unnamed: 0','_id','TimeStamp','PART_FACT_PLAN_DATE','PART_NAME','EQUIP_CD','Reason','Mold_Temperature_1','Mold_Temperature_2','Mold_Temperature_5','Mold_Temperature_6','Mold_Temperature_7',
                 'Mold_Temperature_8','Mold_Temperature_9','Mold_Temperature_10','Mold_Temperature_11','Mold_Temperature_12','Barrel_Temperature_7','Switch_Over_Position','EQUIP_NAME']

# %%
#UnLabeled Drop List
#상기와 비슷

drop_unlabeled_features = ['Unnamed: 0','_id','TimeStamp','PART_FACT_PLAN_DATE','PART_FACT_SERIAL','PART_NAME','EQUIP_NAME','ERR_FACT_QTY',
                           'Mold_Temperature_1','Mold_Temperature_2','Mold_Temperature_5','Mold_Temperature_6','Mold_Temperature_7',
                           'Mold_Temperature_8','Mold_Temperature_9','Mold_Temperature_10','Mold_Temperature_11','Mold_Temperature_12',
                           'Switch_Over_Position','Barrel_Temperature_7','EQUIP_NAME','EQUIP_CD']

# %%
labeled_data.drop(drop_labeled_features, axis = 1, inplace = True)

# %%
unlabeled_data.drop(drop_unlabeled_features, axis = 1, inplace = True)

# %%
labeled_data.head().T
labeled_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2607 entries, 0 to 2606
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   PART_FACT_SERIAL          2607 non-null   int64
#  1   PART_NO                   2607 non-null   object
#  2   PassOrFail                2607 non-null   int64
#  3   Injection_Time            2607 non-null   float64
#  4   Filling_Time              2607 non-null   float64
#  5   Plasticizing_Time         2607 non-null   float64
#  6   Cycle_Time                2607 non-null   float64
#  7   Clamp_Close_Time          2607 non-null   float64
#  8   Cushion_Position          2607 non-null   float64
#  9   Plasticizing_Position     2607 non-null   float64
#  10  Clamp_Open_Position       2607 non-null   float64
#  11  Max_Injection_Speed       2607 non-null   float64
#  12  Max_Screw_RPM             2607 non-null   float64
#  13  Average_Screw_RPM         2607 non-null   float64
#  14  Max_Injection_Pressure    2607 non-null   float64
#  15  Max_Switch_Over_Pressure  2607 non-null   float64
#  16  Max_Back_Pressure         2607 non-null   float64
#  17  Average_Back_Pressure     2607 non-null   float64
#  18  Barrel_Temperature_1      2607 non-null   float64
#  19  Barrel_Temperature_2      2607 non-null   float64
#  20  Barrel_Temperature_3      2607 non-null   float64
#  21  Barrel_Temperature_4      2607 non-null   float64
#  22  Barrel_Temperature_5      2607 non-null   float64
#  23  Barrel_Temperature_6      2607 non-null   float64
#  24  Hopper_Temperature        2607 non-null   float64
#  25  Mold_Temperature_3        2607 non-null   float64
#  26  Mold_Temperature_4        2607 non-null   float64
# dtypes: float64(24), int64(2), object(1)
# memory usage: 550.0+ KB

# %%
unlabeled_data.head().T
unlabeled_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 795315 entries, 0 to 795314
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   PART_NO                   795315 non-null  object
#  1   EQUIP_CD                  795315 non-null  object
#  2   Injection_Time            795315 non-null  float64
#  3   Filling_Time              795315 non-null  float64
#  4   Plasticizing_Time         795315 non-null  float64
#  5   Cycle_Time                795315 non-null  float64
#  6   Clamp_Close_Time          795315 non-null  float64
#  7   Cushion_Position          795315 non-null  float64
#  8   Plasticizing_Position     795315 non-null  float64
#  9   Clamp_Open_Position       795315 non-null  float64
#  10  Max_Injection_Speed       795315 non-null  float64
#  11  Max_Screw_RPM             795315 non-null  float64
#  12  Average_Screw_RPM         795315 non-null  float64
#  13  Max_Injection_Pressure    795315 non-null  float64
#  14  Max_Switch_Over_Pressure  795315 non-null  float64
#  15  Max_Back_Pressure         795315 non-null  float64
#  16  Average_Back_Pressure     795315 non-null  float64
#  17  Barrel_Temperature_1      795315 non-null  float64
#  18  Barrel_Temperature_2      795315 non-null  float64
#  19  Barrel_Temperature_3      795315 non-null  float64
#  20  Barrel_Temperature_4      795315 non-null  float64
#  21  Barrel_Temperature_5      795315 non-null  float64
#  22  Barrel_Temperature_6      795315 non-null  float64
#  23  Hopper_Temperature        795315 non-null  float64
#  24  Mold_Temperature_3        795315 non-null  float64
#  25  Mold_Temperature_4        795315 non-null  float64
# dtypes: float64(24), object(2)
# memory usage: 157.8+ MB

# %%
#Object data 처리
#PART_NO => labeled_data, unlabeled_data => 제품의 모델 코드
#EQUIP_CD => unlabeled_data => 생산한 사출기 호기

#PART_NO

print(labeled_data['PART_NO'].value_counts())
print()
print(unlabeled_data['PART_NO'].value_counts())
print(unlabeled_data['PART_NO'].unique())
# Out:
# 86141AA000    713
# 86131AA000    712
# 86131T1000    591
# 86141T1000    591
# Name: PART_NO, dtype: int64
#
# 87275Q5000    118071
# 87285Q5000    114977
# 87293Q5000     68342
# 86131S8000     40647
# 86141AA000     27885
#                ...
# 9163240030        18
# YP3320L000        10
# 87264R1400         7
# 87274K0000         1
# 87281K0000         1
# Name: PART_NO, Length: 81, dtype: int64
# ['87285Q5000' '87275Q5000' '87263R1400' '86133J7000' 'TM3050L000'
#  'TM3060R000' 'TM1220B003' '87277K0000' '87272K0000' '87282K0000'
#  'YP5740B000' 'YP5750B000' '86611K9000' '87277Q5000' 'UM3060R000'
#  'UM3050L000' 'ON-SS1210' 'TM1200B003' '87293Q5000' '87272R1400'
#  '87282R1400' '87277R1400' 'XG1000F000-1' '87287Q5000' '86134J7000'
#  'XG1000R000-1' '9163240005' 'TM1210B003' '87293K0001' '86131S8000'
#  'ON-SS1110' '86141J7700' '86141S8000' '9163240004' '86131T6000'
#  '87282Q5000' '87272Q5000' '86131G3000' '86132G3000' '9163240003'
#  'YP3330R000' '86142J7700' '87264R1400' 'TL3080R000' 'ON-SS1130'
#  '86131T1000' '87287K0000' '86141T6000' '86141AA000' '87136T1000'
#  '86141T1000' 'DM3050L000' '86131AA000' '87138T1000' '86131G4700'
#  '86132G4700' '86141BC300' '86131BC300' '9163240002' '84721G9000'
#  'DM3120L000' 'DM3060R000' 'QL3060R000' 'QL3050L000' 'YP5440B000'
#  'YP5450B000' 'YP5470B000' 'YP5460B000' '87137T1000' '84721G9900'
#  'TL3050L000' 'TL3060R000' 'YP3320L000' '9163240038' '9163240030'
#  'ON-SS1140' '9163240010' '86141S8900' '87274K0000' '87281K0000'
#  '86131S8900']

# %%
labeled_data['PART_NO'] == '86141AA000'

# %%
# Out:
#   File "<ipython-input-3-4cf4f10edf52>", line 1
#     import
#            ^
# SyntaxError: invalid syntax
